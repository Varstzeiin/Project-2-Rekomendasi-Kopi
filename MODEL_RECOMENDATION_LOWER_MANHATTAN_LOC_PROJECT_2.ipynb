# %% [markdown]
# <a href="https://colab.research.google.com/github/Varstzeiin/Project-2-Rekomendasi-Kopi/blob/main/MODEL_RECOMENDATION_LOWER_MANHATTAN_LOC_PROJECT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODEL FOR PROJECT**

# %% [markdown]
# ## **LM LOCATION**

# %% [markdown]
# ### Install MLxtend library

# %%
pip install -u mlxtend
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Import Library

# %%
df_LM = pd.read_excel('/content/Lowe Manhattan Invoice.xlsx')
df_LM = df_LM.drop(columns=["invoice_id","product_id", "store_id", "unit_price", "Month", "Month.1", "Revenue", "Weekday.1", "Weekday", "Hour"])
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Model

# %%
df_LM['product_detail'] = df_LM['product_detail'].str.strip()
df_LM.dropna(axis = 0, subset = ['new_invoice_id'], inplace = True)
df_LM['new_invoice_id'] = df_LM['new_invoice_id'].astype('str')
df_LM = df_LM[~df_LM['new_invoice_id'].str.contains('C')]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_LM
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       transaction_datetime  transaction_qty   store_location product_category  \
# 0      2023-01-01 07:06:11                2  Lower Manhattan           Coffee
# 1      2023-01-01 07:20:24                1  Lower Manhattan           Coffee
# 2      2023-01-01 07:25:49                1  Lower Manhattan           Coffee
# 3      2023-01-01 07:33:34                2  Lower Manhattan           Coffee
# 4      2023-01-01 07:39:13                1  Lower Manhattan           Coffee
# ...                    ...              ...              ...              ...
# ...

# %%
# membuat basket transaksi
basket = (df_LM
          .groupby(['new_invoice_id', 'product_detail'])['transaction_qty']
          .sum().unstack().reset_index().fillna(0)
          .set_index('new_invoice_id'))
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_detail  Brazilian Lg  Brazilian Rg  Brazilian Sm  Cappuccino  \
# new_invoice_id
# INV00001                 0.0           0.0           0.0         0.0
# INV00002                 0.0           0.0           0.0         0.0
# INV00003                 2.0           2.0           0.0         0.0
# INV00004                 0.0           0.0           2.0         0.0
# INV00005                 0.0           0.0           0.0         0.0
#
# product_detail  Cappuccino Lg  Columbian Medium Roast Lg  \
# new_invoice_id
# INV00001                  0.0                        0.0
# ...

# %%
# encoding data menjadi boolean
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-44-a98055390076>:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)

# %%
basket_sets
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_detail  Brazilian Lg  Brazilian Rg  Brazilian Sm  Cappuccino  \
# new_invoice_id
# INV00001                   0             0             0           0
# INV00002                   0             0             0           0
# INV00003                   1             1             0           0
# INV00004                   0             0             1           0
# INV00005                   0             0             0           0
# ...                      ...           ...           ...         ...
# INV04135                   1             0             1           1
# ...

# %%
# Convert basket to boolean format
basket_sets.astype(bool)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_detail  Brazilian Lg  Brazilian Rg  Brazilian Sm  Cappuccino  \
# new_invoice_id
# INV00001               False         False         False       False
# INV00002               False         False         False       False
# INV00003                True          True         False       False
# INV00004               False         False          True       False
# INV00005               False         False         False       False
# ...                      ...           ...           ...         ...
# INV04135                True         False          True        True
# ...

# %%
# Memakai logaritma apriori
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)
print(f"Frequent Itemsets Found: {len(frequent_itemsets)}")
# Menampilkan rata-rata nilai support
average_support = frequent_itemsets['support'].mean()
print(f"Average Support: {average_support}")
# Mengurutkan frequent itemsets berdasarkan support secara ascending
frequent_itemsets_sorted = frequent_itemsets.sort_values(by='support', ascending=False)
frequent_itemsets_sorted
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.11/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets Found: 80
# Average Support: 0.08244141096883306
#      support                                     itemsets
# 15  0.184344                                      (Latte)
# 10  0.180237                                (Ethiopia Rg)
# 12  0.178787                   (Jamaican Coffee River Lg)
# ...

# %%
frequent_itemsets['itemsets'] = frequent_itemsets['itemsets'].apply(frozenset)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules= association_rules(frequent_itemsets, metric='lift', min_threshold=0.7, support_only=False)

# Print or display the rules
if rules.empty:
    print("aturan asosiasi ga ditemukan. Coba kau kurangi kurangi sikit itu nilai min_support atau min_threshold nya.")
else:
    print(rules.head())
# Out:
#                   antecedents                 consequents  antecedent support  \
# 0              (Brazilian Lg)              (Brazilian Sm)            0.163083
# 1              (Brazilian Sm)              (Brazilian Lg)            0.172022
# 2              (Brazilian Lg)  (Jamaican Coffee River Lg)            0.163083
# 3  (Jamaican Coffee River Lg)              (Brazilian Lg)            0.178787
# 4              (Brazilian Lg)  (Jamaican Coffee River Sm)            0.163083
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.172022  0.052187    0.320000  1.860225               1.0
# 1            0.163083  0.052187    0.303371  1.860225               1.0
# 2            0.178787  0.051703    0.317037  1.773265               1.0
# 3            0.163083  0.051703    0.289189  1.773265               1.0
# 4            0.173472  0.051945    0.318519  1.836139               1.0
#
# ...

# %%
# Sorting rules by lift to identify the best associations
rules = rules.sort_values(by='lift', ascending=False)
average_rules = rules['lift'].mean()
print(f"Average Lift of Lower Manhattan: {average_rules}")
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
# Average Lift of Lower Manhattan: 1.7729414317367405
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      antecedents                    consequents   support  \
# 74   (Columbian Medium Roast Sm)     (Jamaican Coffee River Sm)  0.054119
# 75    (Jamaican Coffee River Sm)    (Columbian Medium Roast Sm)  0.054119
# 105   (Jamaican Coffee River Sm)                     (Latte Rg)  0.058710
# 104                   (Latte Rg)     (Jamaican Coffee River Sm)  0.058710
# 22                (Brazilian Rg)  (Our Old Time Diner Blend Sm)  0.051703
# ..                           ...                            ...       ...
# ...

# %% [markdown]
# # **IMPLEMENTASI**

# %%
def recommend_products_interactive(rules, top_n=3, min_lift=0.7):
    while True:
        print("\n--- Coffee Product Recommendation System ---")
        selected_products = input("Enter purchased product(s) separated by commas (or type 'exit' to quit): ").strip()
        if selected_products.lower() == 'exit':
            print("Exiting the system. Have a great day!")
            break
        selected_products = [product.strip() for product in selected_products.split(',')]

        # Generate recommendations
        recommendations = []
        for _, row in rules.iterrows():
            if any(product in row['antecedents'] for product in selected_products):
                if row['lift'] >= min_lift:  # Filter by minimum lift value
                    recommendations.extend(list(row['consequents']))

        # Remove already selected products from recommendations
        recommendations = list(set(recommendations) - set(selected_products))

        # Sort recommendations by lift (descending)
        recommendations = sorted(recommendations, key=lambda x: get_lift_for_recommendation(x, selected_products, rules), reverse=True)

        if recommendations:
            print(f"Top {top_n} recommendations based on your selection: {recommendations[:top_n]}")
        else:
            print("No recommendations found for the selected product(s).")

def get_lift_for_recommendation(product, selected_products, rules):
    """Helper function to get lift value for a given product recommendation."""
    for _, row in rules.iterrows():
        if product in row['consequents'] and any(sel_product in row['antecedents'] for sel_product in selected_products):
            return row['lift']
    return 0

# Example usage
recommend_products_interactive(rules)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# --- Coffee Product Recommendation System ---
# Enter purchased product(s) separated by commas (or type 'exit' to quit): Latte
# Top 3 recommendations based on your selection: ['Latte Rg', 'Brazilian Rg', 'Ethiopia Sm']
#
# --- Coffee Product Recommendation System ---
# Enter purchased product(s) separated by commas (or type 'exit' to quit): exit
# Exiting the system. Have a great day!

# %%
# Kesimpulan rekomendasi
print("The top associations have been identified. Use the recommendation system to suggest products to customers in real-time.")
# Out:
# The top associations have been identified. Use the recommendation system to suggest products to customers in real-time.
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
